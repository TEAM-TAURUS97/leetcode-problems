// %% [markdown]
// There is a special square room with mirrors on each of the four walls. Except for the southwest corner, there are receptors on each of the remaining corners, numbered 0, 1, and 2.
//
// The square room has walls of length p and a laser ray from the southwest corner first meets the east wall at a distance q from the 0th receptor.
//
// Given the two integers p and q, return the number of the receptor that the ray meets first.
//
// The test cases are guaranteed so that the ray will meet a receptor eventually.
//
//
// Output: 2![reflection.png](attachment:reflection.png)
//
//
// Example 1:
//
// Input: p = 2, q = 1
//
// Explanation: The ray meets receptor 2 the first time it gets reflected back to the left wall.
//
// Example 2:
//
// Input: p = 3, q = 1
//
// Output: 1
//
// Constraints:
//
// 1 <= q <= p <= 1000

// %%
public int mirrorReflection(int p, int q) {
    while (q % 2 == 0 && p % 2 == 0) {
        q = q / 2;
        p = p / 2;
    }
    if (q % 2 == 0 && p % 2 != 0) return 0;
    if (q % 2 != 0 && p % 2 != 0) return 1;
    if (q % 2 != 0 && p % 2 == 0) return 2;
    return -1;
}

System.out.println("p:2 , q:1 => receptor = " + mirrorReflection(2,1));
System.out.println("p:3 , q:1 => receptor = " + mirrorReflection(3,1));
System.out.println("p:3 , q:2 => receptor = " + mirrorReflection(3,2));
// Out:
// p:2 , q:1 => receptor = 2
// p:3 , q:1 => receptor = 1
// p:3 , q:2 => receptor = 0
